# %% [markdown]
# ## SFS

# %%
# %run imports.ipynb

# %%
maf_min = 0.01
r2_value = 0.1
downsample_n = 100000

# %%
metadata = pd.read_csv('meta.csv', sep=",", index_col=0)
metadata
# Out:
#                  src_code population        country     location         site  \
# ox_code
# AA0040-C  Twifo_Praso__E2      GHcol          Ghana  Twifo Praso  Twifo Praso
# AA0041-C  Twifo_Praso__H3      GHcol          Ghana  Twifo Praso  Twifo Praso
# AA0042-C      Takoradi_C7      GHcol          Ghana     Takoradi     Takoradi
# AA0043-C      Takoradi_H8      GHcol          Ghana     Takoradi     Takoradi
# AA0044-C     Takoradi_D10      GHcol          Ghana     Takoradi     Takoradi
# ...                   ...        ...            ...          ...          ...
# AY0087-C       Tia_dPM_46      CIcol  Cote d'Ivoire     Tiassale     Tiassale
# AY0088-C       Tia_dPM_52      CIcol  Cote d'Ivoire     Tiassale     Tiassale
# AY0089-C        Tia_aPM_4      CIcol  Cote d'Ivoire     Tiassale     Tiassale
# AY0090-C       Tia_aPM_13      CIcol  Cote d'Ivoire     Tiassale     Tiassale
# AY0091-C       Tia_aPM_37      CIcol  Cote d'Ivoire     Tiassale     Tiassale
#
#             contributor        contact  year m_s sex  n_sequences  \
# ox_code
# AA0040-C  David Weetman  David Weetman  2012   M   F     95033368
# AA0041-C  David Weetman  David Weetman  2012   M   F     95843804
# AA0042-C  David Weetman  David Weetman  2012   M   F    107420666
# AA0043-C  David Weetman  David Weetman  2012   M   F     95993752
# AA0044-C  David Weetman  David Weetman  2012   M   F    103044262
# ...                 ...            ...   ...  ..  ..          ...
# AY0087-C  David Weetman  David Weetman  2012   M   F    101458232
# AY0088-C  David Weetman  David Weetman  2012   M   F     95140584
# AY0089-C  David Weetman  David Weetman  2012   M   F     92383724
# AY0090-C  David Weetman  David Weetman  2012   M   F     96210618
# AY0091-C  David Weetman  David Weetman  2012   M   F     95973872
#
#           mean_coverage ebi_sample_acc  latitude  longitude structure
# ox_code
# AA0040-C          30.99      ERS311878   5.60858   -1.54926       col
# AA0041-C          31.70      ERS311886   5.60858   -1.54926       col
# AA0042-C          35.65      ERS311894   4.91217   -1.77397       col
# AA0043-C          29.46      ERS311902   4.91217   -1.77397       col
# AA0044-C          33.67      ERS311910   4.91217   -1.77397       col
# ...                 ...            ...       ...        ...       ...
# AY0087-C          32.56      ERS311822   5.89839   -4.82293       col
# AY0088-C          30.75      ERS311830   5.89839   -4.82293       col
# AY0089-C          29.04      ERS311838   5.89839   -4.82293       col
# AY0090-C          30.94      ERS311846   5.89839   -4.82293       col
# AY0091-C          31.30      ERS311854   5.89839   -4.82293       col
#
# [505 rows x 16 columns]

# %%
callset_fn = callset_biallel

# %%
pop_selection = metadata.structure.isin({'col', 'gam', 'adx'}).values

# %% [markdown]
# ----------------------------------------
# ## 3R

# %%
fh = callset_fn['3R']

# %%
from itertools import compress

# %%
fh_samples = [str(s) for s in callset_fn['3R']["samples"][:]]
fh_samples = list(compress(fh_samples, pop_selection))

# %%
len(list(compress(fh_samples, pop_selection)))
# Out:
# 505

# %%
g = allel.GenotypeChunkedArray(fh['calldata/GT']).subset(sel1=pop_selection)
g
# Out:
# <GenotypeChunkedArray shape=(10752701, 505, 2) dtype=int8 chunks=(5251, 505, 2)
#    nbytes=10.1G cbytes=474.6M cratio=21.8
#    compression=blosc compression_opts={'cname': 'lz4', 'clevel': 5, 'shuffle': 1, 'blocksize': 0}
#    values=zarr.core.Array>

# %%
positions = fh['variants']['POS'][:]
loci = (positions >= 1) & (positions <= 24_000_000)

# %%
g =g.compress(loci, axis=0)

# %%
pos = np.compress(loci, positions)
positions = None

# %%
alleles = g.count_alleles()

# %%
biallelic = alleles.max_allele() <= 1
g = g.compress(biallelic, axis=0)
pos = np.compress(np.array(biallelic), pos)

# %%
freqs = g.count_alleles().to_frequencies()
maf_ok = np.min(np.array(freqs), axis=1) >= maf_min
g = g.compress(maf_ok, axis=0)
pos = np.compress(maf_ok, pos, axis=0)

# %%
if pos.size > downsample_n:
        print("Downsampling... to {0} from {1}".format(downsample_n, pos.size))
        idx = np.random.choice(np.arange(0, pos.size), downsample_n, False)
        idx.sort()
        pos = np.take(pos, idx)
        g = g.take(idx, axis=0)
# Out:
# Downsampling... to 100000 from 864309

# %%
g_3R = g
g_3R
# Out:
# <GenotypeChunkedArray shape=(100000, 505, 2) dtype=int8 chunks=(782, 505, 2)
#    nbytes=96.3M cbytes=20.2M cratio=4.8
#    compression=blosc compression_opts={'cname': 'lz4', 'clevel': 5, 'shuffle': 1, 'blocksize': 0}
#    values=zarr.core.Array>

# %% [markdown]
# --------------------------------------
# ## 3L

# %%
fh = callset_fn['3L']

# %%
from itertools import compress

# %%
fh_samples = [str(s) for s in callset_fn['3L']["samples"][:]]
fh_samples = list(compress(fh_samples, pop_selection))

# %%
len(list(compress(fh_samples, pop_selection)))
# Out:
# 505

# %%
g = allel.GenotypeChunkedArray(fh['calldata/GT']).subset(sel1=pop_selection)
g
# Out:
# <GenotypeChunkedArray shape=(7897666, 505, 2) dtype=int8 chunks=(3857, 505, 2)
#    nbytes=7.4G cbytes=341.3M cratio=22.3
#    compression=blosc compression_opts={'cname': 'lz4', 'clevel': 5, 'shuffle': 1, 'blocksize': 0}
#    values=zarr.core.Array>

# %%
positions = fh['variants']['POS'][:]
loci = (positions >= 18_000_000) & (positions <= 41_000_000)

# %%
g =g.compress(loci, axis=0)
g
# Out:
# <GenotypeChunkedArray shape=(5358122, 505, 2) dtype=int8 chunks=(2617, 505, 2)
#    nbytes=5.0G cbytes=221.6M cratio=23.3
#    compression=blosc compression_opts={'cname': 'lz4', 'clevel': 5, 'shuffle': 1, 'blocksize': 0}
#    values=zarr.core.Array>

# %%
pos = np.compress(loci, positions)
positions = None

# %%
alleles = g.count_alleles()

# %%
biallelic = alleles.max_allele() <= 1
g = g.compress(biallelic, axis=0)
pos = np.compress(np.array(biallelic), pos)

# %%
freqs = g.count_alleles().to_frequencies()
maf_ok = np.min(np.array(freqs), axis=1) >= maf_min
g = g.compress(maf_ok, axis=0)
pos = np.compress(maf_ok, pos, axis=0)

# %%
if pos.size > downsample_n:
        print("Downsampling... to {0} from {1}".format(downsample_n, pos.size))
        idx = np.random.choice(np.arange(0, pos.size), downsample_n, False)
        idx.sort()
        pos = np.take(pos, idx)
        g = g.take(idx, axis=0)
# Out:
# Downsampling... to 100000 from 809122

# %%
g_3L = g
g_3L
# Out:
# <GenotypeChunkedArray shape=(100000, 505, 2) dtype=int8 chunks=(782, 505, 2)
#    nbytes=96.3M cbytes=20.1M cratio=4.8
#    compression=blosc compression_opts={'cname': 'lz4', 'clevel': 5, 'shuffle': 1, 'blocksize': 0}
#    values=zarr.core.Array>

# %% [markdown]
# ------------------------------
# ## Merge two genomes

# %%
g_3R
# Out:
# <GenotypeChunkedArray shape=(100000, 505, 2) dtype=int8 chunks=(782, 505, 2)
#    nbytes=96.3M cbytes=20.2M cratio=4.8
#    compression=blosc compression_opts={'cname': 'lz4', 'clevel': 5, 'shuffle': 1, 'blocksize': 0}
#    values=zarr.core.Array>

# %%
g_3L
# Out:
# <GenotypeChunkedArray shape=(100000, 505, 2) dtype=int8 chunks=(782, 505, 2)
#    nbytes=96.3M cbytes=20.1M cratio=4.8
#    compression=blosc compression_opts={'cname': 'lz4', 'clevel': 5, 'shuffle': 1, 'blocksize': 0}
#    values=zarr.core.Array>

# %%
chrom_3 = np.vstack((g_3R, g_3L))
chrom_3 =allel. GenotypeChunkedArray(chrom_3)

# %%
chrom_3
# Out:
# <GenotypeChunkedArray shape=(200000, 505, 2) dtype=int8
#    nbytes=192.6M
#    values=numpy.ndarray>

# %% [markdown]
# ----------------------------------

# %%
positions
# Out:
# array([    9790,     9791,     9798, ..., 41956537, 41956541, 41956551],
#       dtype=int32)

# %%
variants_pass = variants.compress(pos)
variants_pass
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-51-ae0ee93291b5> in <module>
# ----> 1 variants_pass = variants.compress(pos)
#       2 variants_pass
#
# NameError: name 'variants' is not defined

# %%
metadata = pd.read_csv('meta.csv', sep=",")

# %%
subpops = {
    'all': list(range(len(metadata))),
    'gam': metadata[metadata.structure == 'gam'].index.tolist(),
    'col': metadata[metadata.structure == 'col'].index.tolist(),
    'adx': metadata[metadata.structure == 'adx'].index.tolist(),

}
subpops['gam'][:5]
# Out:
# [5, 7, 14, 15, 21]

# %%
# %%time
ac_subpops = chrom_3.count_alleles_subpops(subpops, max_allele=3)
ac_subpops
# Out:
# CPU times: user 1.77 s, sys: 0 ns, total: 1.77 s
# Wall time: 1.77 s
# <AlleleCountsChunkedTable shape=(200000,) dtype=[('adx', '<i4', (4,)), ('all', '<i4', (4,)), ('col', '<i4', (4,)), ('gam', '<i4', (4,))]
#    nbytes=12.2M cbytes=2.8M cratio=4.4
#    values=allel.chunked.storage_zarr.ZarrTable>

# %%
for pop in 'all', 'gam', 'col', 'adx':
    print(pop, ac_subpops[pop].count_segregating())
# Out:
# all 200000
# gam 196640
# col 195414
# adx 195485

# %%
is_seg = ac_subpops['all'].is_segregating()[:]
is_seg
# Out:
# array([ True,  True,  True, ...,  True,  True,  True])

# %%
genotypes_seg = chrom_3.compress(is_seg, axis=0)
genotypes_seg
# Out:
# <GenotypeChunkedArray shape=(200000, 505, 2) dtype=int8 chunks=(1563, 505, 2)
#    nbytes=192.6M cbytes=40.3M cratio=4.8
#    compression=blosc compression_opts={'cname': 'lz4', 'clevel': 5, 'shuffle': 1, 'blocksize': 0}
#    values=zarr.core.Array>

# %%
ac_seg = ac_subpops.compress(is_seg)
ac_seg
# Out:
# <AlleleCountsChunkedTable shape=(200000,) dtype=[('adx', '<i4', (4,)), ('all', '<i4', (4,)), ('col', '<i4', (4,)), ('gam', '<i4', (4,))]
#    nbytes=12.2M cbytes=2.8M cratio=4.4
#    values=allel.chunked.storage_zarr.ZarrTable>

# %%
jsfs = allel.joint_sfs(ac_seg['gam'][:, 1], ac_seg['col'][:, 1])
fig, ax = plt.subplots(figsize=(6, 6))
allel.plot_joint_sfs(jsfs, ax=ax)
ax.set_ylabel('Alternate allele count, gam')
ax.set_xlabel('Alternate allele count, col');

# %%
jsfs = allel.joint_sfs(ac_seg['gam'][:, 1], ac_seg['adx'][:, 1])
fig, ax = plt.subplots(figsize=(6, 6))
allel.plot_joint_sfs(jsfs, ax=ax)
ax.set_ylabel('Alternate allele count, gam')
ax.set_xlabel('Alternate allele count, adx');

# %%
jsfs = allel.joint_sfs(ac_seg['col'][:, 1], ac_seg['adx'][:, 1])
fig, ax = plt.subplots(figsize=(6, 6))
allel.plot_joint_sfs(jsfs, ax=ax)
ax.set_ylabel('Alternate allele count, col')
ax.set_xlabel('Alternate allele count, adx');

# %% [markdown]
# -------------------------

# %%
is_biallelic_01 = ac_subpops['all'].is_biallelic_01()[:]
ac1 = ac_subpops['col'].compress(is_biallelic_01, axis=0)[:, :2]
ac2 = ac_subpops['gam'].compress(is_biallelic_01, axis=0)[:, :2]
ac3 = ac_subpops['adx'].compress(is_biallelic_01, axis=0)[:, :2]

# %%
fig, ax = plt.subplots(figsize=(15, 10))
sns.despine(ax=ax, offset=10)
sfs1 = allel.sfs_folded_scaled(ac1)
allel.plot_sfs_folded_scaled(sfs1, ax=ax, label='col', n=ac1.sum(axis=1).max())
sfs2 = allel.sfs_folded_scaled(ac2)
allel.plot_sfs_folded_scaled(sfs2, ax=ax, label='gam', n=ac2.sum(axis=1).max())
sfs3 = allel.sfs_folded_scaled(ac3)
allel.plot_sfs_folded_scaled(sfs3, ax=ax, label='adx', n=ac3.sum(axis=1).max())
ax.legend()
ax.set_title('Scaled folded site frequency spectra')
# workaround bug in scikit-allel re axis naming
ax.set_xlabel('minor allele frequency');
