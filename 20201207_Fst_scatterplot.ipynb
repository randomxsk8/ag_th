# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
fst = pd.read_csv('fst.csv',names=['pop1', 'pop2', 'Fst'], sep = ';').iloc[1:]

# %%
df = fst.pivot(index='pop1', columns='pop2', values='Fst')

# %%
df = df.fillna(df.T)

# %%
df
# Out:
# pop2   BFcol  BFgam  CIcol  GHcol  GHgam     GM  GNcol  GNgam     GW
# pop1
# BFcol    NaN  0.067  0.013  0.014  0.069  0.057  0.048  0.067  0.049
# BFgam  0.067    NaN  0.072  0.074  0.008  0.046  0.098  0.001  0.050
# CIcol  0.013  0.072    NaN  0.008  0.073  0.056  0.041  0.073  0.047
# GHcol  0.014  0.074  0.008    NaN  0.075  0.058  0.045  0.074  0.049
# GHgam  0.069  0.008  0.073  0.075    NaN  0.050  0.099  0.009  0.053
# GM     0.057  0.046  0.056  0.058  0.050    NaN  0.076  0.046  0.011
# GNcol  0.048  0.098  0.041  0.045  0.099  0.076    NaN  0.098  0.065
# GNgam  0.067  0.001  0.073  0.074  0.009  0.046  0.098    NaN  0.050
# GW     0.049  0.050  0.047  0.049  0.053  0.011  0.065  0.050    NaN

# %%
# Generate a mask for the upper triangle
mask = np.triu(np.ones_like(df, dtype=bool))

# Set up the matplotlib figure
f, ax = plt.subplots(figsize=(11, 9))

# Generate a custom diverging colormap
cmap = sns.diverging_palette(240, 10, as_cmap=True)

# Draw the heatmap with the mask and correct aspect ratio
sns.heatmap(df, mask=mask, cmap=cmap, vmax=.3, center=0,
            square=True, linewidths=.5,annot=True, cbar_kws={"shrink": .5})
# Out:
# <AxesSubplot:xlabel='pop2', ylabel='pop1'>

# %% [markdown]
# -----------------------

# %%
fst
# Out:
#      pop1   pop2    Fst
# 1   BFcol     GM  0.057
# 2   BFcol     GW  0.049
# 3   GNcol     GM  0.076
# 4   GNcol     GW  0.065
# 5   CIcol     GM  0.056
# 6   CIcol     GW  0.047
# 7   GHcol     GM  0.058
# 8   GHcol     GW  0.049
# 9   GHgam     GM  0.050
# 10  GHgam     GW  0.053
# 11  BFgam     GM  0.046
# 12  BFgam     GW  0.050
# 13  GNgam     GM  0.046
# 14  GNgam     GW  0.050
# 15     GM     GW  0.011
# 16     GW     GM  0.011
# 17  GHgam  BFcol  0.069
# 18  GHgam  GNcol  0.099
# 19  GHgam  CIcol  0.073
# 20  GHgam  GHcol  0.075
# 21  BFgam  BFcol  0.067
# 22  BFgam  GNcol  0.098
# 23  BFgam  CIcol  0.072
# 24  BFgam  GHcol  0.074
# 25  GNgam  BFcol  0.067
# 26  GNgam  GNcol  0.098
# 27  GNgam  CIcol  0.073
# 28  GNgam  GHcol  0.074
# 29  GHgam  BFgam  0.008
# 30  GHgam  GNgam  0.009
# 31  BFgam  GHgam  0.008
# 32  BFgam  GNgam  0.001
# 33  GNgam  GHgam  0.009
# 34  GNgam  BFgam  0.001
# 35  BFcol  GNcol  0.048
# 36  BFcol  CIcol  0.013
# 37  BFcol  GHcol  0.014
# ...

# %%
fst1 = fst.iloc[0:8,:]
fst1
# Out:
#     pop1 pop2    Fst
# 1  BFcol   GM  0.057
# 2  BFcol   GW  0.049
# 3  GNcol   GM  0.076
# 4  GNcol   GW  0.065
# 5  CIcol   GM  0.056
# 6  CIcol   GW  0.047
# 7  GHcol   GM  0.058
# 8  GHcol   GW  0.049

# %%
fst2 = fst.iloc[8:18,:]
fst2
# Out:
#      pop1   pop2    Fst
# 9   GHgam     GM  0.050
# 10  GHgam     GW  0.053
# 11  BFgam     GM  0.046
# 12  BFgam     GW  0.050
# 13  GNgam     GM  0.046
# 14  GNgam     GW  0.050
# 15     GM     GW  0.011
# 16     GW     GM  0.011
# 17  GHgam  BFcol  0.069
# 18  GHgam  GNcol  0.099

# %%
fst3 = fst.iloc[16:28,:]
fst3
# Out:
#      pop1   pop2    Fst
# 17  GHgam  BFcol  0.069
# 18  GHgam  GNcol  0.099
# 19  GHgam  CIcol  0.073
# 20  GHgam  GHcol  0.075
# 21  BFgam  BFcol  0.067
# 22  BFgam  GNcol  0.098
# 23  BFgam  CIcol  0.072
# 24  BFgam  GHcol  0.074
# 25  GNgam  BFcol  0.067
# 26  GNgam  GNcol  0.098
# 27  GNgam  CIcol  0.073
# 28  GNgam  GHcol  0.074

# %%
fst4 = fst.iloc[28:34,:]
fst4
# Out:
#      pop1   pop2    Fst
# 29  GHgam  BFgam  0.008
# 30  GHgam  GNgam  0.009
# 31  BFgam  GHgam  0.008
# 32  BFgam  GNgam  0.001
# 33  GNgam  GHgam  0.009
# 34  GNgam  BFgam  0.001

# %%
fst5 = fst.iloc[34:,:]
fst5
# Out:
#      pop1   pop2    Fst
# 35  BFcol  GNcol  0.048
# 36  BFcol  CIcol  0.013
# 37  BFcol  GHcol  0.014
# 38  GNcol  BFcol  0.048
# 39  GNcol  CIcol  0.041
# 40  GNcol  GHcol  0.045
# 41  CIcol  BFcol  0.013
# 42  CIcol  GNcol  0.041
# 43  CIcol  GHcol  0.008
# 44  GHcol  BFcol  0.014
# 45  GHcol  GNcol  0.045
# 46  GHcol  CIcol  0.008

# %%
fst6 = fst.iloc[17,:]
fst6
# Out:
# pop1    GHgam
# pop2    GNcol
# Fst     0.099
# Name: 18, dtype: object

# %%
fst6["Data"] = "GM_vs_GW"
# Out:
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# /opt/conda/lib/python3.7/site-packages/pandas/core/indexing.py:670: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   iloc._setitem_with_indexer(indexer, value)

# %%
fst1["Data"] = "col_vs_FW"
fst2["Data"] = "gam_vs_FW"
fst3["Data"] = "gam_vs_col"
fst4["Data"] = "gam_vs_gam"
fst5["Data"] = "col_vs_col"
# Out:
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...

# %%
times = [fst1, fst2, fst3,fst4,fst5,fst6]
allTimes = pd.concat(times)

# %%
plt.figure()
allTimes.boxplot(by="Data")
# Out:
# <AxesSubplot:title={'center':'Fst'}, xlabel='[Data]'>

# %%
sns.set_style("whitegrid") 
sns.boxplot(x = 'Data', y = 'val', data = allTimes, )
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-18-b0306c305af8> in <module>
#       1 sns.set_style("whitegrid")
# ----> 2 sns.boxplot(x = 'Data', y = 'val', data = allTimes, )
#
# /opt/conda/lib/python3.7/site-packages/seaborn/categorical.py in boxplot(x, y, hue, data, order, hue_order, orient, color, palette, saturation, width, dodge, fliersize, linewidth, whis, ax, **kwargs)
#    2233     plotter = _BoxPlotter(x, y, hue, data, order, hue_order,
#    2234                           orient, color, palette, saturation,
# -> 2235                           width, dodge, fliersize, linewidth)
#    2236
#    2237     if ax is None:
#
# /opt/conda/lib/python3.7/site-packages/seaborn/categorical.py in __init__(self, x, y, hue, data, order, hue_order, orient, color, palette, saturation, width, dodge, fliersize, linewidth)
# ...

# %%
sns.set(rc={'figure.figsize':(11.7,8.27)})

# %% [markdown]
# -------------------------------

# %%
gm_col = pd.read_csv('fst/gm_col.txt', sep = '\t')
gm_col
# Out:
#     pop1 pop2    Fst
# 0  BFcol   GM  0.057
# 1  GNcol   GM  0.076
# 2  CIcol   GM  0.056
# 3  GHcol   GM  0.058

# %%
gm_gam = pd.read_csv('fst/gm_gam.txt', sep = '\t')
gm_gam
# Out:
#     pop1 pop2    Fst
# 0  GHgam   GM  0.050
# 1  BFgam   GM  0.046
# 2  GNgam   GM  0.046

# %%
gw_col = pd.read_csv('fst/gw_col.txt', sep = '\t')
gw_col
# Out:
#     pop1 pop2    Fst
# 0  BFcol   GW  0.049
# 1  GNcol   GW  0.065
# 2  CIcol   GW  0.047
# 3  GHcol   GW  0.049

# %%
gw_gam = pd.read_csv('fst/gw_gam.txt', sep = '\t')
gw_gam
# Out:
#     pop1 pop2    Fst
# 0  GHgam   GW  0.053
# 1  BFgam   GW  0.050
# 2  GNgam   GW  0.050

# %%
gm_col["Data"] = "col_vs_GM"
gm_gam["Data"] = "gam_vs_GM"
gw_col["Data"] = "col_vs_GW"
gw_gam["Data"] = "gam_vs_GW"
fst3["Data"] = "gam_vs_col"
fst4["Data"] = "gam_vs_gam"
fst5["Data"] = "col_vs_col"
# Out:
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...

# %%
times = [gm_col, gm_gam, gw_col,gw_gam,fst3,fst4,fst5]
allTimes = pd.concat(times)

# %%
sns.set_style("whitegrid") 

sns.boxplot(x = 'Data', y = 'Fst', data = allTimes) 
sns.despine()

# %%
np.mean(fst4)
# Out:
# Fst    0.006
# dtype: float64

# %%
len(fst3)
# Out:
# 12

# %%
allTimes
# Out:
#      pop1   pop2    Fst        Data
# 0   BFcol     GM  0.057   col_vs_GM
# 1   GNcol     GM  0.076   col_vs_GM
# 2   CIcol     GM  0.056   col_vs_GM
# 3   GHcol     GM  0.058   col_vs_GM
# 0   GHgam     GM  0.050   gam_vs_GM
# 1   BFgam     GM  0.046   gam_vs_GM
# 2   GNgam     GM  0.046   gam_vs_GM
# 0   BFcol     GW  0.049   col_vs_GW
# 1   GNcol     GW  0.065   col_vs_GW
# 2   CIcol     GW  0.047   col_vs_GW
# 3   GHcol     GW  0.049   col_vs_GW
# 0   GHgam     GW  0.053   gam_vs_GW
# 1   BFgam     GW  0.050   gam_vs_GW
# 2   GNgam     GW  0.050   gam_vs_GW
# 17  GHgam  BFcol  0.069  gam_vs_col
# 18  GHgam  GNcol  0.099  gam_vs_col
# 19  GHgam  CIcol  0.073  gam_vs_col
# 20  GHgam  GHcol  0.075  gam_vs_col
# 21  BFgam  BFcol  0.067  gam_vs_col
# 22  BFgam  GNcol  0.098  gam_vs_col
# 23  BFgam  CIcol  0.072  gam_vs_col
# 24  BFgam  GHcol  0.074  gam_vs_col
# 25  GNgam  BFcol  0.067  gam_vs_col
# 26  GNgam  GNcol  0.098  gam_vs_col
# 27  GNgam  CIcol  0.073  gam_vs_col
# ...

# %%
import numpy as np
import scipy.stats


def mean_confidence_interval(data, confidence=0.95):
    a = 1.0 * np.array(data)
    n = len(a)
    m, se = np.mean(a), scipy.stats.sem(a)
    h = se * scipy.stats.t.ppf((1 + confidence) / 2., n-1)
    return m, m-h, m+h

# %%
df1 = allTimes[allTimes.Data == 'gam_vs_GW']
df1
# Out:
#     pop1 pop2    Fst       Data
# 0  GHgam   GW  0.053  gam_vs_GW
# 1  BFgam   GW  0.050  gam_vs_GW
# 2  GNgam   GW  0.050  gam_vs_GW

# %%
mean_confidence_interval(df1.Fst)
# Out:
# (0.05100000000000001, 0.04669734727008874, 0.05530265272991128)

# %%
mean_confidence_interval(allTimes.Data == 'col_vs_col')
# Out:
# (0.2727272727272727, 0.13575952157659024, 0.4096950238779552)

# %%
mean_confidence_interval(allTimes.Data == 'gam_vs_GM')
# Out:
# (0.06818181818181818, -0.009336665454056453, 0.1457003018176928)

# %%
allTimes[allTimes.Data=='gam_vs_GM'].mean()
# Out:
# Fst    0.047333
# dtype: float64

# %%
df1[df1.Data=='gam_vs_GM']
# Out:
# Empty DataFrame
# Columns: [pop1, pop2, Fst, Data]
# Index: []
